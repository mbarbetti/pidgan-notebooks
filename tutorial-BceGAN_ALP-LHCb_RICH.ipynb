# %% [markdown]
# # Parameterizing the LHCb RICH system using the pidgan `BceGAN_ALP` algorithm
#
# **Author:** [mbarbetti](https://github.com/mbarbetti)
#
# **Date created:** 16/10/2023
#
# **Last modified:** 07/11/2023

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mbarbetti/pidgan-notebooks/blob/main/tutorial-BceGAN_ALP-LHCb_RICH.ipynb)
# [![Open In Kaggle](https://kaggle.com/static/images/open-in-kaggle.svg)](https://kaggle.com/kernels/welcome?src=https://github.com/mbarbetti/pidgan-notebooks/blob/main/tutorial-BceGAN_ALP-LHCb_RICH.ipynb)
# [![Open in GitHub](https://img.shields.io/badge/Open_in_GitHub-blue?style=flat&logo=github&logoColor=white&labelColor=555)](https://github.com/mbarbetti/pidgan-notebooks/blob/main/tutorial-BceGAN_GP-LHCb_RICH.ipynb)
#
# **Description:** This tutorial demonstrates how to parameterize the high-level response of the LHCb RICH system using a Generative Adversarial Network (GAN) [[1][1]]. The code is written using the [pidgan](https://github.com/mbarbetti/pidgan) package that relies on TensorFlow and Keras as backends.
#
# [1]: https://arxiv.org/abs/1406.2661

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### What is LHCb?
#
# The [**LHCb experiment**](https://lhcb-outreach.web.cern.ch) has been originally designed to study rare decays of particles containing $b$ and $c$ quarks produced at the Large Hadron Collider (LHC). The LHCb detector, shown in the background of the following photo, is a single-arm forward spectrometer covering the pseudorapidity range of $2 < \eta < 5$. The detector includes:
#
# - **Tracking system** - used for high-precision measurements of the momentum of charged particles and the position of the primary vertices
# - **Particle Identification (PID) system** - used to distiguish different species of traversing particles (i.e., muons, pions, kaons, protons)

# %% [markdown]
# <div align="center">
#   <img src="https://raw.githubusercontent.com/mbarbetti/pidgan-notebooks/main/.github/images/lhcb.jpeg" width="800"/>
# </div>

# %% [markdown]
# #### The RICH detectors
#
# The LHCb PID system counts two ring-imaging Cherenkov ([RICH](https://lhcb-outreach.web.cern.ch/detector/rich-detectors/)) detectors whose response allows to separate different types of charged hadrons (e.g., pions, kaons, protons) using the [Cherenkov radiation](https://en.wikipedia.org/wiki/Cherenkov_radiation) of the traversing particles. The size of the circles produced by the Cherenkov radiation (shown on the left) within the RICH detector is related to the mass of the emitting particle. Reconstructing such circles allows to distinguish particles accordingly to their species (shown on the right).

# %% [markdown]
# <div align="center">
#   <img src="https://raw.githubusercontent.com/mbarbetti/pidgan-notebooks/main/.github/images/rich-response.png" width="300"/>
#   <img src="https://raw.githubusercontent.com/mbarbetti/pidgan-notebooks/main/.github/images/rich-performance.png" width="400"/>
# </div>

# %% [markdown]
# ### What are GANs?
#
# Generative Adversarial Networks [[1][1]] are a powerful class of _generative models_ based on the simultaneous training of two neural networks:
#
# *  **Discriminator network** ($D$) - trained by a classification task to separate the generator output from the reference dataset
# * **Generator network** ($G$) - trained by a simulation task to reproduce the reference dataset trying to fake the discriminator
#
# The goal is that $D$ optimally discriminates on the origin of the two samples, and simultaneously the training procedure for $G$ is to maximize the _probability_ of $D$ making a mistake. This framework corresponds to a **minimax two-player game** [[1][1]].
#
# Traditional GAN systems suffer from many issues, particularly during the training phase:
#
# * the generator may _collapse_ producing only a single sample or a small family of very similar samples (**mode collapse**)
# * the two players may _oscillate_ during training rather than converging to the [**Nash equilibrium**](https://en.wikipedia.org/wiki/Nash_equilibrium)
# * if _imbalance_ between the two players occurs, then the system is incapable of learning at all
#
# All these drawbacks result from the [**vanishing gradient problem**](https://en.wikipedia.org/wiki/Vanishing_gradient_problem), namely the lack of information for the update of the $G$ parameters. This is due to the saturation of the $D$ that is so good in distinguishing the origin of the two samples that no errors remain to the $G$ to improve the generated space [[2][2]]. To fix the problem, we need to avoid the discriminator saturation, for example constraining the $D$ response to be a **1-Lipschitz function** as suggested for the WGAN systems [[3][3]] in Ref. [[4][4]].
#
# [1]: https://arxiv.org/abs/1406.2661
# [2]: https://arxiv.org/abs/1701.04862
# [3]: https://arxiv.org/abs/1701.07875
# [4]: https://arxiv.org/abs/1907.05681

# %% [markdown]
# <div align="center">
#   <img src="https://raw.githubusercontent.com/mbarbetti/pidgan-notebooks/main/.github/images/gan-scheme.png" width="800"/>
# </div>

# %% [markdown]
# #### Mathematical details
#
# The generator $G(z)$, fed by elements $z$ sampled according to a known distribution $p_z$ (typically gaussian), maps the **latent space** $\mathcal{Z}$ to the reference dataset $\mathcal{X}$, inducing a distribution $p_\rm{gen}$ trained to match with the target distribution $p_\rm{ref}$. The discriminator $D(x)$ outputs a single scalar, readable as the **probability** that $x$ comes from the reference dataset rather than $G$. Hence, the optimization problem corresponds to train $D$ to maximize the probability of correct labelling, and simultaneously training $G$ to hinder the discriminator task.
#
# To define the discriminator **loss function** $\mathcal{L}^{D}_{\rm{BceGAN}}$ we can use the [binary cross-entropy](https://en.wikipedia.org/wiki/Cross-entropy) as suggested in Ref. [[5][5]]:
#
# <center>$\mathcal{L}^{D}_{\rm{BceGAN}} (\theta_d, \theta_g) = \frac{1}{2} \left ( {\rm{BCE}}_{x \sim p_\rm{ref}} \left ( \mathbb{1}, D_{\theta_d}(x) \right ) + {\rm{BCE}}_{z \sim p_\rm{z}} \left ( \mathbb{0}, D_{\theta_d}(G_{\theta_g}(z)) \right ) \right )$</center>
#
# where $\mathbb{1}$ and $\mathbb{0}$ are the labels for true and generated data respectively. The generator loss function $\mathcal{L}^{G}_{\rm{BceGAN}}$ follows a similar design:
#
# <center>$\mathcal{L}^{G}_{\rm{BceGAN}} (\theta_d, \theta_g) = {\rm{BCE}}_{z \sim p_\rm{z}} \left ( \mathbb{1}, D_{\theta_d}(G_{\theta_g}(z)) \right )$</center>
#
# Hence, the _minimax game_ of the **BceGAN-ALP algorithm** can be written in this form:
#
# <center>$\begin{cases}
# \displaystyle{\min_G} \, \mathcal{L}^{G}_{\rm{BceGAN}} (\theta_d, \theta_g)\\
# \displaystyle{\min_D} \, \mathcal{L}^{D}_{\rm{BceGAN}} (\theta_d, \theta_g) + \lambda \, \mathbb{E}_{x \sim p_{\rm{ref, gen}}} \left ( \frac{\left | D_{\theta_d}(x) - D_{\theta_d}(x + r_{adv}) \right |}{\| r_{adv} \|_2} - 1 \right )^2
# \end{cases}$</center>
#
# where, to avoid _vanishing gradient issues_, the disccriminator is **explicitly** constrained to induce a 1-Lipschitz function through a regularization term called **adversarial Lipschitz penalty** (ALP), further described in Ref. [[4][4]].
#
# [4]: https://arxiv.org/abs/1907.05681
# [5]: https://arxiv.org/abs/1511.06434

# %% [markdown]
# #### Using input conditions
#
# Feeding the generator with additional information besides the latent space sample allows to **conditionate** its output. In particular, it's sufficient to concatenate the conditional features $x$ to the random noise $z$ passed as input to $G$ to make it able to take into account this information [[6][6]]: $y_{\rm{gen}}(x) = G(x, z)$. Obviously, to preserve the capability to learn through the minimax game, also the discriminator must be fed by the additional features $x$, simply concatenating them to either elements of the reference sample or of the generated space [[6][6]]: $D(x, y)$ with $y \in \{y_{\rm{ref}}, y_{\rm{gen}}\}$.
#
# [6]: https://arxiv.org/abs/1606.03498

# %% [markdown]
# ## Tutorial
#
# The aim of this tutorial is to build a parameterization of the LHCb RICH detectors. Since we expect that the high-level response of the RICH system only depends on the kinematics of the traversing particles and the detector occupancy, the former can be parameterized training a **BceGAN-ALP model** properly conditioned [[6][6], [7][7]]. The pidgan package provides several GAN [`algorithms`](https://github.com/mbarbetti/pidgan/tree/main/src/pidgan/algorithms) implementing some of the most used tricks presented in the literature to stablize their training [[3][3], [4][4], [8][8]]. The pidgan [`players`](https://github.com/mbarbetti/pidgan/tree/main/src/pidgan/players), namely the generator and discriminator networks, are designed to be trained taking conditions as input. In this notebook we will see how to build a model for the RICH system using the pidgan [`BceGAN_ALP`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/algorithms/BceGAN_ALP.py) algorithm.
#
# [1]: https://arxiv.org/abs/1406.2661
# [2]: https://arxiv.org/abs/1701.04862
# [3]: https://arxiv.org/abs/1701.07875
# [4]: https://arxiv.org/abs/1907.05681
# [5]: https://arxiv.org/abs/1511.06434
# [6]: https://arxiv.org/abs/1411.1784
# [7]: https://arxiv.org/abs/1905.11825
# [8]: https://arxiv.org/abs/1606.03498

# %% [markdown]
# ### Install
#
# The first step is to install the [pidgan](https://github.com/mbarbetti/pidgan) package and some other ones that are typically needed in machine learning applications to High Energy Physics (i.e., uproot, scipy, scikit-learn, matplotlib).

# %%
# %%capture
# !pip install pidgan[hep]

# %% [markdown]
# Now, let's verify the correct installation of pidgan printing its version:

# %%
import pidgan

pidgan.__version__
# Out:
# '0.0.7'

# %% [markdown]
# In case you're running this notebook on a machine equipped with a GPU, let's also verify the correct installation of TensorFlow:

# %%
import tensorflow as tf

tf.config.list_physical_devices("GPU")  # outputs a non-empty list in case of GPU equipped
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Finally, we just have to import all the modules that we will use in the following code cells:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from datetime import datetime
from tensorflow import keras
from sklearn.utils import shuffle
from sklearn.preprocessing import QuantileTransformer

# %% [markdown]
# ### Data loading
#
# The data needed for this tutorial is provided through a CSV file downloadable from the [pidgan-notebooks](https://github.com/mbarbetti/pidgan-notebooks) repository.
#
# **Disclaimer:** The data results from a toy model inspired to the LHCb RICH system combining its high-level response when traversed by a set of long-lived charged particles, namely muons, pions, kaons and protons.
#
# The CSV file contains 250000 instances, 4 input features and 4 output features. Let's import the data as a pandas [`DataFrame`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html):

# %%
url = "https://raw.githubusercontent.com/mbarbetti/pidgan-notebooks/main/data/pidgan-toy-data.csv"
data = pd.read_csv(url)

data.describe()
# Out:
#                    P            ETA        nTracks    trackcharge  \
# count  250000.000000  250000.000000  250000.000000  250000.000000
# mean    19112.579988       3.362231     180.468471       0.021152
# std     22610.408265       0.770202      91.626085       0.999778
# min      3000.090800       1.800331       9.000999      -1.000000
# 25%      5970.525000       2.749856     116.000000      -1.000000
# 50%     10983.800000       3.340136     164.000000       1.000000
# 75%     22392.768000       3.949773     228.000000       1.000000
# max    199837.420000       5.434650     739.993000       1.000000
#
#             RichDLLe      RichDLLmu       RichDLLk       RichDLLp
# count  250000.000000  250000.000000  250000.000000  250000.000000
# mean       -8.959810      -1.853031      -3.614234      -3.626358
# std        16.090133      11.512878      28.799922      28.006328
# min      -140.804340    -110.494200    -149.289830    -149.591670
# 25%       -12.259203      -3.784543     -16.768035     -18.402633
# 50%        -3.499332      -0.634627       1.748902       1.705883
# 75%        -0.179516       0.651420      14.155344      15.179315
# max        58.021923     106.868935     120.245310     110.364006

# %% [markdown]
# We expect that the response of the RICH detectors only depends on the **kinematics** of the traversing particles and the **detector occupancy**. Hence, to build the aimed parameterization, we will conditionate the generator training using the following information:
# * `data.P` - momentum in GeV/$c$ of the traversing parrticles
# * `data.ETA` - pseudorapidity of the traversing particles
# * `data.nTracks` - total number of reconstructed tracks describing the detector occupancy
# * `data.trackcharge` - charge of the traversing particles (boolean value)

# %%
plt.figure(figsize=(24, 5))

plt.subplot(1, 3, 1)
plt.xlabel("Momentum [GeV/$c$]", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(data["P"]/1e3, bins=np.linspace(0.0, 200.0, 101), color="#3288bd", label="toy data")
plt.legend(loc="upper right", fontsize=10)
plt.yscale("log")

plt.subplot(1, 3, 2)
plt.xlabel("Pseudorapidity", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(data["ETA"], bins=np.linspace(1.5, 5.5, 101), color="#3288bd", label="toy data")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 3, 3)
plt.xlabel("$\mathtt{nTracks}$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(data["nTracks"], bins=np.linspace(0.0, 750.0, 101), color="#3288bd", label="toy data")
plt.legend(loc="upper right", fontsize=10)

plt.show()

# %% [markdown]
# The high-level response of the RICH detectors describes how good the reconstructed circles match with a specific particle hypothesis in terms of **differential log-likelihood** (DLL). We aim to build a model able to reproduce the following output features:
# * `data.RichDLLe` - RICH DLL between the electron and pion tracks
# * `data.RichDLLmu` - RICH DLL between the muon and pion tracks
# * `data.RichDLLk` - RICH DLL between the kaon and pion tracks
# * `data.RichDLLp` - RICH DLL between the proton and pion tracks

# %%
plt.figure(figsize=(16, 10))

plt.subplot(2, 2, 1)
plt.xlabel("RICH differential log-likelihood $(e - \pi)$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(data["RichDLLe"], bins=np.linspace(-150.0, 150.0, 101), color="#3288bd", label="toy data")
plt.legend(loc="upper right", fontsize=10)
plt.yscale("log")

plt.subplot(2, 2, 2)
plt.xlabel("RICH differential log-likelihood $(\mu - \pi)$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(data["RichDLLmu"], bins=np.linspace(-150.0, 150.0, 101), color="#3288bd", label="toy data")
plt.legend(loc="upper right", fontsize=10)
plt.yscale("log")

plt.subplot(2, 2, 3)
plt.xlabel("RICH differential log-likelihood $(K - \pi)$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(data["RichDLLk"], bins=np.linspace(-150.0, 150.0, 101), color="#3288bd", label="toy data")
plt.legend(loc="upper right", fontsize=10)
plt.yscale("log")

plt.subplot(2, 2, 4)
plt.xlabel("RICH differential log-likelihood $(p - \pi)$", fontsize=12)
plt.ylabel("Candidates", fontsize=12)
plt.hist(data["RichDLLp"], bins=np.linspace(-150.0, 150.0, 101), color="#3288bd", label="toy data")
plt.legend(loc="upper right", fontsize=10)
plt.yscale("log")

plt.show()

# %% [markdown]
# ### Data preprocessing
#
# As usual in a machine learning application, the data sample is split into **training** and **test set**.

# %%
data = shuffle(data)

x_vars = ["P", "ETA", "nTracks", "trackcharge"]
x = data[x_vars].values

y_vars = ["RichDLLe", "RichDLLmu", "RichDLLk", "RichDLLp"]
y = data[y_vars].values

x_train, x_test = x[:150000], x[150000:]
y_train, y_test = y[:150000], y[150000:]

print(f"x_train shape: {x_train.shape} \t x_test shape: {x_test.shape}")
print(f"y_train shape: {y_train.shape} \t y_test shape: {y_test.shape}")
# Out:
# x_train shape: (150000, 4) 	 x_test shape: (100000, 4)
# y_train shape: (150000, 4) 	 y_test shape: (100000, 4)

# %% [markdown]
# To normalize the different ranges and orders of magnitude of input $x$ and output $y$ features highlighted by the previous histograms, we will use the scikit-learn [`QuantileTransformer`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.QuantileTransformer.html) using a Gaussian as output distribution.
#
# Since one of the $x$ features is boolean (`data.trackcharge`), the latter should be kept unchanged. Let's preprocess the rest of the conditional information and verify the results with the [`DataFrame`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) `describe()` method:

# %%
x_scaler = QuantileTransformer(output_distribution="normal")
x_train_prep = x_scaler.fit_transform(x_train[:, :3])
x_train_prep = np.c_[x_train_prep, x_train[:, 3]]

pd.DataFrame(x_train_prep, columns=x_vars).describe()
# Out:
#                    P            ETA        nTracks    trackcharge
# count  150000.000000  150000.000000  150000.000000  150000.000000
# mean       -0.000943      -0.008795       0.008200       0.023120
# std         0.997962       0.988568       1.002927       0.999736
# min        -5.199338      -5.199338      -5.199338      -1.000000
# 25%        -0.672517      -0.690513      -0.656486      -1.000000
# 50%        -0.007669      -0.015127       0.007527       1.000000
# 75%         0.658642       0.667010       0.683178       1.000000
# max         5.199338       5.199338       5.199338       1.000000

# %% [markdown]
# Let's preprocess also the $y$ features checking what obtained:

# %%
y_scaler = QuantileTransformer(output_distribution="normal")
y_train_prep = y_scaler.fit_transform(y_train)

pd.DataFrame(y_train_prep, columns=y_vars).describe()
# Out:
#             RichDLLe      RichDLLmu       RichDLLk       RichDLLp
# count  150000.000000  150000.000000  150000.000000  150000.000000
# mean       -0.013508       0.014120       0.013613       0.003095
# std         0.993664       1.006052       1.016559       1.000050
# min        -5.199338      -5.199338      -5.199338      -5.199338
# 25%        -0.688552      -0.678563      -0.666778      -0.668894
# 50%        -0.016266       0.002965       0.021895       0.010071
# 75%         0.651896       0.687499       0.685884       0.677480
# max         5.199338       5.199338       5.199338       5.199338

# %% [markdown]
# ### Model definition
#
# We are finally ready to define the **BceGAN-ALP model** to be used to parameterize the RICH response. GAN algorithms rely on the competition (namely the minimax game) between the generator and discriminator networks. The latters are provided by the [pidgan](https://github.com/mbarbetti/pidgan) package through the [`players`](https://github.com/mbarbetti/pidgan/tree/main/src/pidgan/players) module that implements the two networks customizing the TensorFlow [`Model`](https://www.tensorflow.org/api_docs/python/tf/keras/Model) class.

# %% [markdown]
# #### The generator
#
# The **generator player** can be implemented with the high-level [`Generator`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/players/generators/Generator.py) class that provides the neural network model wrapping the TensorFlow [Sequential API](https://www.tensorflow.org/guide/keras/sequential_model). Before to initialize a `Generator` instance, let's have a look at its arguments:
#
# * **`output_dim`** (_int_) - Dimensionality of the generator output space.
# * **`latent_dim`** (_int_) - Dimensionality of the latent space.
# * **`num_hidden_layers`** (_int_, default=5) - Number of the hidden layers passed to the [`tf.keras.Sequential`](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential) model. Each hidden layer has a LeakyReLU as activation function (see [`tf.keras.layers.LeakyReLU`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LeakyReLU)).
# * **`mlp_hidden_units`** (_int_ or _array_like_, default=128) - Number of neuron units per each hidden layer. It can also be passed as an array of unit numbers having length equal to the number of hidden layers.
# * **`mlp_dropout_rates`** (_float_ or _array_like_, default=0.0) - Fraction of the input neurons to drop per each hidden layer. It can also be passed as an array of float numbers having length equal to the number of hidden layers.
# * **`output_activation`** (_activation_like_ or _None_, default=None) - Activation function to use in the generator output layer (see [`tf.keras.activations`](https://www.tensorflow.org/api_docs/python/tf/keras/activations)). If None, no activation is applied (i.e., "linear" activation: $a(x) = x$).
# * **`name`** (_str_ of _None_, default=None) - The name of the generator model.
# * **`dtype`** (_dtype_ or _None_, default=None) - The dtype of the generator layer computations and weights.

# %%
from pidgan.players.generators import Generator

generator = Generator(
    output_dim=y.shape[-1],
    latent_dim=64,
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_dropout_rates=0.0,
    output_activation=None,
    name="generator"
)

# %%
_ = generator(keras.Input(shape=x.shape[1:]))
generator.summary()
# Out:
# Model: "generator_seq"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_0 (Dense)             (None, 128)               8832
#
#  leaky_relu_0 (LeakyReLU)    (None, 128)               0
#
#  dropout_0 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  leaky_relu_1 (LeakyReLU)    (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  leaky_relu_2 (LeakyReLU)    (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  leaky_relu_3 (LeakyReLU)    (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  leaky_relu_4 (LeakyReLU)    (None, 128)               0
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_out (Dense)           (None, 4)                 516
#
# =================================================================
# Total params: 75396 (294.52 KB)
# Trainable params: 75396 (294.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### The discriminator
#
# The **discriminator player** can be implemented with the high-level [`Discriminator`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/players/discriminators/Discriminator.py) class that provides the neural network model wrapping the TensorFlow [Sequential API](https://www.tensorflow.org/guide/keras/sequential_model). Again, before to initialize a `Discriminator` instance, let's have a look to its arguments:
#
# * **`output_dim`** (_int_) - Dimensionality of the discriminator output space.
# * **`num_hidden_layers`** (_int_, default=5) - Number of the hidden layers passed to the [`tf.keras.Sequential`](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential) model. Each hidden layer has a LeakyReLU as activation function (see [`tf.keras.layers.LeakyReLU`](https://www.tensorflow.org/api_docs/python/tf/keras/layers/LeakyReLU)).
# * **`mlp_hidden_units`** (_int_ or _array_like_, default=128) - Number of neuron units per each hidden layer. It can also be passed as an array of unit numbers having length equal to the number of hidden layers.
# * **`mlp_dropout_rates`** (_float_ or _array_like_, default=0.0) - Fraction of the input neurons to drop per each hidden layer. It can also be passed as an array of float numbers having length equal to the number of hidden layers.
# * **`output_activation`** (_activation_like_ or _None_, default="sigmoid") - Activation function to use in the dicriminator output layer (see [`tf.keras.activations`](https://www.tensorflow.org/api_docs/python/tf/keras/activations)). If None, no activation is applied (i.e., "linear" activation: $a(x) = x$).
# * **`name`** (_str_ of _None_, default=None) - The name of the discriminator model.
# * **`dtype`** (_dtype_ or _None_, default=None) - The dtype of the discriminator layer computations and weights.

# %%
from pidgan.players.discriminators import Discriminator

discriminator = Discriminator(
    output_dim=1,
    num_hidden_layers=5,
    mlp_hidden_units=128,
    mlp_dropout_rates=0.0,
    output_activation=None,
    name="discriminator"
)

# %%
_ = discriminator((keras.Input(shape=x.shape[1:]), keras.Input(shape=y.shape[1:])))
discriminator.summary()
# Out:
# Model: "discriminator_seq"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_0 (Dense)             (None, 128)               1152
#
#  leaky_relu_0 (LeakyReLU)    (None, 128)               0
#
#  dropout_0 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  leaky_relu_1 (LeakyReLU)    (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  leaky_relu_2 (LeakyReLU)    (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 128)               16512
#
#  leaky_relu_3 (LeakyReLU)    (None, 128)               0
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  leaky_relu_4 (LeakyReLU)    (None, 128)               0
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_out (Dense)           (None, 1)                 129
#
# =================================================================
# Total params: 67329 (263.00 KB)
# Trainable params: 67329 (263.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### The BceGAN-ALP algorithm
#
# The **BceGAN-ALP algorithm** [[4][4], [5][5]] can be implemented with the high-level [`BceGAN_ALP`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/algorithms/BceGAN_ALP.py) class that defines the training procedure of the two players customizing the TensorFlow [`Model`](https://www.tensorflow.org/api_docs/python/tf/keras/Model) class and, in particular, its `fit()` method. Once again, before to initialize a `BceGAN_ALP` instance, let's have a look at its arguments:
#
# * **`generator`** (_generator_like_) - The generator network. It must be passed as a pidgan [`Generator`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/players/generators/Generator.py) instance.
# * **`discriminator`** (_discriminator_like_) - The discriminator network. It must be passed as a pidgan [`Discriminator`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/players/discriminators/Discriminator.py) instance.
# * **`lipschitz_penalty`** (_float_, default=1.0) - Importance of the regularization term GP that implicitly constrains the discriminator to induce a 1-Lipschitz function as proposed in Ref. [[4][4]].
# * **`lipschitz_penalty_strategy`** (_str_, default="one-sided") - If "two-sided" is passed, the Lipschitz constant computed along the virtual adversarial direction is forced to be equal to 1. When "one-sided" is preferred, only Lipschitz constant values greater than 1 are penalized.
# * **`feature_matching_penalty`** (_float_, default=0.0) - Importance of the regularization term added to the generator training to force the hidden state of the discriminator to match between reference and generated examples. Its design follows from what proposed in Ref. [[8][8]].
# * **`referee`** (_classifier_like_ or _None_, default=None) - When passed it enables the training of a third independent player: the referee network. It can be used to assess the quality of the generator output during the training. If passed, it must be a pidgan [`Classifier`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/players/classifiers/Classifier.py) instance.
# * **`name`** (_str_ or _None_, default="BceGAN_ALP") - The name of the BceGAN-ALP model.
# * **`dtype`** (_dtype_ or _None_, default=None) - The dtype of the BceGAN-ALP model computations.
#
# [4]: https://arxiv.org/abs/1704.00028
# [5]: https://arxiv.org/abs/1511.06434
# [8]: https://arxiv.org/abs/1606.03498

# %% [markdown]
# To not further complicate this tutorial, we avoid to use the referee network in this case, even if its initialization is straightforward:
#
# ```python
# from pidgan.players.classifiers import Classifier
#
# referee = Classifier(
#     num_hidden_layers=5,
#     mlp_hidden_units=128,
#     mlp_dropout_rates=0.0,
#     name="referee"
# )
# ```
#
# It's time to initialize a [`BceGAN_ALP`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/algorithms/BceGAN_ALP.py) instance!

# %%
from pidgan.algorithms import BceGAN_ALP

gan = BceGAN_ALP(
    generator=generator,
    discriminator=discriminator,
    lipschitz_penalty=1.0,
    lipschitz_penalty_strategy="one-sided",
    feature_matching_penalty=0.0,
    referee=None,
    name="BceGAN_ALP",
)

# %% [markdown]
# #### Model compilation
#
# To finalize the [`BceGAN_ALP`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/algorithms/BceGAN_ALP.py) model preparation before to run the training procedure, we need to execute the `compile()` method. Differently from the TensorFlow `compile()` method, the [pidgan](https://github.com/mbarbetti/pidgan) one doesn't require to pass the loss function since it is encoded in the customized `gan.fit()` method. The arguments of the `gan.compile()` method follows:
#
# * **`metrics`** (_list_ or _None_, default=None) - If not None, list of metrics to be evaluated by the BceGAN-GP model during training and testing. Each of this can be a string (name of a built-in pidgan function) or a [`pidgan.metrics`](https://github.com/mbarbetti/pidgan/tree/main/src/pidgan/metrics) instance.
# * **`generator_optimizer`** (_optimizer_like_, default="rmsprop") - String (name of optimizer) or optimizer instance for the generator network (see [`tf.keras.optimizers`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)).
# * **`discriminator_optimizer`** (_optimizer_like_, default="rmsprop") - String (name of optimizer) or optimizer instance for the discriminator network. (see [`tf.keras.optimizers`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)).
# * **`generator_upds_per_batch`** (_int_, default=1) - Number of the generator weights updates per batch of data.
# * **`discriminator_upds_per_batch`** (_int_, default=1) - Number of the discriminator weights updates per batch of data.
# * **`virtual_adv_direction_upds`** (_int_, default=1) - Number of iterations to approximate the virtual adversarial direction per discriminator update as proposed in Ref. [[4][4]].
# * **`referee_optimizer`** (_optimizer_like_ or _None_, default=None) - If not None, string (name of optimizer) or optimizer instance for the referee network (see [`tf.keras.optimizers`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)).
# * **`referee_upds_per_batch`** (_int_ or _None_, default=None) - If not None, number of the referee weights updates per batch of data.
#
# [4]: https://arxiv.org/abs/1907.05681

# %%
gan.compile(
    metrics=["wass_dist"],
    generator_optimizer=keras.optimizers.RMSprop(learning_rate=0.002),
    discriminator_optimizer=keras.optimizers.RMSprop(learning_rate=0.001),
    generator_upds_per_batch=1,
    discriminator_upds_per_batch=1,
    virtual_adv_direction_upds=1,
    referee_optimizer=None,
    referee_upds_per_batch=None,
)

# %% [markdown]
# ### Training procedure
#
# The [pidgan](https://github.com/mbarbetti/pidgan) package provides several learning rate scheduling strategies through the [`callbacks.schedulers`](https://github.com/mbarbetti/pidgan/tree/main/src/pidgan/callbacks/schedulers) module. The pidgan schedulers are designed as [custom TensorFlow callbacks](https://www.tensorflow.org/guide/keras/writing_your_own_callbacks) that also allow to trace the learning rate value of each passed optimizer during the training. In this tutorial, we will use an exponential decay schedule both for the generator and discriminator networks:
#
# <center>$\eta(t) = \eta_0 \cdot e^{- \alpha \cdot t / \tau}$</center>
#
# where $\eta(t)$ indicates the learning rate value at a specific training step $t$, $\eta_0$ the initial learning rate, $\alpha$ the decay rate and $\tau$ the decay step.

# %%
from pidgan.callbacks.schedulers import LearnRateExpDecay

schedules = list()

g_lr_sched = LearnRateExpDecay(
    gan.generator_optimizer,
    decay_rate=0.1,
    decay_steps=50000,
    min_learning_rate=1e-6,
    verbose=True,
    key="g_lr",
)
schedules.append(g_lr_sched)

d_lr_sched = LearnRateExpDecay(
    gan.discriminator_optimizer,
    decay_rate=0.1,
    decay_steps=75000,
    min_learning_rate=1e-6,
    verbose=True,
    key="d_lr",
)
schedules.append(d_lr_sched)

# %% [markdown]
# Calling `gan.fit()` allows to perform the **minimax two-player game**, training the generator to reproduce the reference space $y$ on the basis of the conditions $x$ thanks to the discriminator feedbacks. The arguments taken by the pidgan `fit()` method are the same ones traditionally passed to a TensorFlow [`Model`](https://www.tensorflow.org/api_docs/python/tf/keras/Model) instance. The schedulers are passed through the `callbacks` argument and, since their verbosity has been enabled (`verbose` and `key` passed), the learning rates of both the generator and discriminator are printed during the training procedure.
#
# **Note:** Training the [`BceGAN_ALP`](https://github.com/mbarbetti/pidgan/blob/main/src/pidgan/algorithms/BceGAN_ALP.py) model on Colab using the hyperparameters chosen for this tutorial (i.e., batch-size, epochs, updates per batch) takes about 25 minutes with no-GPU equipped or 15 minutes enabling the T4-powered runtime.

# %%
start = datetime.now()

train = gan.fit(
    x=x_train_prep,
    y=y_train_prep,
    batch_size=256,
    epochs=100,
    validation_split=0.3,
    callbacks=schedules,
    verbose=1,
)

stop = datetime.now()

print(f"Training procedure completed in {stop - start}")
# Out:
# Epoch 1/100
#   4/411 [..............................] - ETA: 8s - g_loss: 0.6815 - d_loss: 0.6837 - wass_dist: -0.1582 - g_lr: 0.0020 - d_lr: 9.9995e-04
# WARNING:tensorflow:Callback method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0158s vs `on_train_batch_begin` time: 0.3771s). Check your callbacks.
# 411/411 [==============================] - 28s 38ms/step - g_loss: 0.7409 - d_loss: 0.6906 - wass_dist: -0.0107 - g_lr: 0.0020 - d_lr: 9.9372e-04 - val_g_loss: 0.7061 - val_d_loss: 0.6930 - val_wass_dist: -0.0069
# Epoch 2/100
# 411/411 [==============================] - 11s 26ms/step - g_loss: 0.6980 - d_loss: 0.6933 - wass_dist: -0.0193 - g_lr: 0.0019 - d_lr: 9.8126e-04 - val_g_loss: 0.6906 - val_d_loss: 0.6934 - val_wass_dist: 0.0011
# Epoch 3/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6963 - d_loss: 0.6931 - wass_dist: -0.0279 - g_lr: 0.0019 - d_lr: 9.6895e-04 - val_g_loss: 0.7015 - val_d_loss: 0.6928 - val_wass_dist: -0.0022
# Epoch 4/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6958 - d_loss: 0.6932 - wass_dist: -0.0040 - g_lr: 0.0019 - d_lr: 9.5680e-04 - val_g_loss: 0.6945 - val_d_loss: 0.6929 - val_wass_dist: -0.0017
# Epoch 5/100
# 411/411 [==============================] - 10s 25ms/step - g_loss: 0.6953 - d_loss: 0.6932 - wass_dist: -0.0020 - g_lr: 0.0018 - d_lr: 9.4481e-04 - val_g_loss: 0.6866 - val_d_loss: 0.6943 - val_wass_dist: 0.0045
# Epoch 6/100
# 411/411 [==============================] - 11s 28ms/step - g_loss: 0.6948 - d_loss: 0.6932 - wass_dist: -0.0082 - g_lr: 0.0018 - d_lr: 9.3296e-04 - val_g_loss: 0.6944 - val_d_loss: 0.6926 - val_wass_dist: -0.0018
# Epoch 7/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6948 - d_loss: 0.6931 - wass_dist: -0.0237 - g_lr: 0.0018 - d_lr: 9.2126e-04 - val_g_loss: 0.6918 - val_d_loss: 0.6938 - val_wass_dist: 0.0076
# Epoch 8/100
# 411/411 [==============================] - 10s 25ms/step - g_loss: 0.6948 - d_loss: 0.6932 - wass_dist: -0.0065 - g_lr: 0.0017 - d_lr: 9.0971e-04 - val_g_loss: 0.6899 - val_d_loss: 0.6936 - val_wass_dist: 0.0045
# Epoch 9/100
# 411/411 [==============================] - 8s 18ms/step - g_loss: 0.6949 - d_loss: 0.6933 - wass_dist: -0.0077 - g_lr: 0.0017 - d_lr: 8.9830e-04 - val_g_loss: 0.6885 - val_d_loss: 0.6936 - val_wass_dist: 8.3218e-04
# Epoch 10/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6949 - d_loss: 0.6932 - wass_dist: -6.5551e-05 - g_lr: 0.0017 - d_lr: 8.8704e-04 - val_g_loss: 0.6919 - val_d_loss: 0.6929 - val_wass_dist: -0.0013
# Epoch 11/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6944 - d_loss: 0.6932 - wass_dist: 0.0073 - g_lr: 0.0016 - d_lr: 8.7592e-04 - val_g_loss: 0.6922 - val_d_loss: 0.6935 - val_wass_dist: 0.0046
# Epoch 12/100
# 411/411 [==============================] - 8s 18ms/step - g_loss: 0.6945 - d_loss: 0.6932 - wass_dist: -0.0078 - g_lr: 0.0016 - d_lr: 8.6493e-04 - val_g_loss: 0.6915 - val_d_loss: 0.6936 - val_wass_dist: -0.0015
# Epoch 13/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6944 - d_loss: 0.6932 - wass_dist: -0.0161 - g_lr: 0.0016 - d_lr: 8.5409e-04 - val_g_loss: 0.6924 - val_d_loss: 0.6935 - val_wass_dist: 0.0022
# Epoch 14/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6944 - d_loss: 0.6931 - wass_dist: -0.0046 - g_lr: 0.0015 - d_lr: 8.4338e-04 - val_g_loss: 0.6955 - val_d_loss: 0.6931 - val_wass_dist: 0.0011
# Epoch 15/100
# 411/411 [==============================] - 10s 24ms/step - g_loss: 0.6944 - d_loss: 0.6932 - wass_dist: -5.5715e-04 - g_lr: 0.0015 - d_lr: 8.3280e-04 - val_g_loss: 0.6931 - val_d_loss: 0.6933 - val_wass_dist: -5.2782e-05
# Epoch 16/100
# 411/411 [==============================] - 9s 22ms/step - g_loss: 0.6941 - d_loss: 0.6932 - wass_dist: 0.0019 - g_lr: 0.0015 - d_lr: 8.2236e-04 - val_g_loss: 0.6944 - val_d_loss: 0.6933 - val_wass_dist: -6.9900e-04
# Epoch 17/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6946 - d_loss: 0.6931 - wass_dist: -8.0500e-04 - g_lr: 0.0015 - d_lr: 8.1205e-04 - val_g_loss: 0.6949 - val_d_loss: 0.6930 - val_wass_dist: 4.7914e-04
# Epoch 18/100
# 411/411 [==============================] - 7s 18ms/step - g_loss: 0.6944 - d_loss: 0.6932 - wass_dist: 0.0035 - g_lr: 0.0014 - d_lr: 8.0187e-04 - val_g_loss: 0.6910 - val_d_loss: 0.6938 - val_wass_dist: 0.0052
# Epoch 19/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6942 - d_loss: 0.6932 - wass_dist: 1.2461e-04 - g_lr: 0.0014 - d_lr: 7.9181e-04 - val_g_loss: 0.6922 - val_d_loss: 0.6931 - val_wass_dist: -6.6735e-04
# Epoch 20/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6946 - d_loss: 0.6931 - wass_dist: -0.0086 - g_lr: 0.0014 - d_lr: 7.8189e-04 - val_g_loss: 0.6969 - val_d_loss: 0.6932 - val_wass_dist: 0.0019
# Epoch 21/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6947 - d_loss: 0.6931 - wass_dist: -0.0160 - g_lr: 0.0014 - d_lr: 7.7208e-04 - val_g_loss: 0.6939 - val_d_loss: 0.6934 - val_wass_dist: 0.0012
# Epoch 22/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6947 - d_loss: 0.6931 - wass_dist: -4.4363e-05 - g_lr: 0.0013 - d_lr: 7.6240e-04 - val_g_loss: 0.6982 - val_d_loss: 0.6929 - val_wass_dist: 7.3189e-04
# Epoch 23/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6952 - d_loss: 0.6930 - wass_dist: -0.0044 - g_lr: 0.0013 - d_lr: 7.5284e-04 - val_g_loss: 0.6982 - val_d_loss: 0.6932 - val_wass_dist: 0.0011
# Epoch 24/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6945 - d_loss: 0.6932 - wass_dist: -0.0036 - g_lr: 0.0013 - d_lr: 7.4340e-04 - val_g_loss: 0.6924 - val_d_loss: 0.6928 - val_wass_dist: -0.0014
# Epoch 25/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6947 - d_loss: 0.6931 - wass_dist: 2.7270e-04 - g_lr: 0.0013 - d_lr: 7.3408e-04 - val_g_loss: 0.6972 - val_d_loss: 0.6937 - val_wass_dist: -6.4661e-04
# Epoch 26/100
# 411/411 [==============================] - 7s 18ms/step - g_loss: 0.6943 - d_loss: 0.6932 - wass_dist: -0.0010 - g_lr: 0.0012 - d_lr: 7.2487e-04 - val_g_loss: 0.6971 - val_d_loss: 0.6929 - val_wass_dist: -3.9953e-04
# Epoch 27/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6943 - d_loss: 0.6932 - wass_dist: -0.0066 - g_lr: 0.0012 - d_lr: 7.1579e-04 - val_g_loss: 0.7002 - val_d_loss: 0.6938 - val_wass_dist: 0.0047
# Epoch 28/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6944 - d_loss: 0.6930 - wass_dist: -0.0194 - g_lr: 0.0012 - d_lr: 7.0681e-04 - val_g_loss: 0.6868 - val_d_loss: 0.6925 - val_wass_dist: -0.0017
# Epoch 29/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6947 - d_loss: 0.6931 - wass_dist: -0.0049 - g_lr: 0.0012 - d_lr: 6.9795e-04 - val_g_loss: 0.6940 - val_d_loss: 0.6932 - val_wass_dist: -0.0016
# Epoch 30/100
# 411/411 [==============================] - 9s 23ms/step - g_loss: 0.6945 - d_loss: 0.6931 - wass_dist: -0.0049 - g_lr: 0.0011 - d_lr: 6.8920e-04 - val_g_loss: 0.6950 - val_d_loss: 0.6928 - val_wass_dist: -4.1136e-04
# Epoch 31/100
# 411/411 [==============================] - 10s 24ms/step - g_loss: 0.6943 - d_loss: 0.6931 - wass_dist: 0.0077 - g_lr: 0.0011 - d_lr: 6.8055e-04 - val_g_loss: 0.6901 - val_d_loss: 0.6930 - val_wass_dist: 0.0032
# Epoch 32/100
# 411/411 [==============================] - 8s 18ms/step - g_loss: 0.6949 - d_loss: 0.6930 - wass_dist: -0.0075 - g_lr: 0.0011 - d_lr: 6.7202e-04 - val_g_loss: 0.6943 - val_d_loss: 0.6934 - val_wass_dist: -0.0014
# Epoch 33/100
# 411/411 [==============================] - 9s 22ms/step - g_loss: 0.6948 - d_loss: 0.6932 - wass_dist: -0.0031 - g_lr: 0.0011 - d_lr: 6.6359e-04 - val_g_loss: 0.6943 - val_d_loss: 0.6929 - val_wass_dist: -0.0028
# Epoch 34/100
# 411/411 [==============================] - 9s 22ms/step - g_loss: 0.6955 - d_loss: 0.6929 - wass_dist: -0.0022 - g_lr: 0.0011 - d_lr: 6.5527e-04 - val_g_loss: 0.7010 - val_d_loss: 0.6933 - val_wass_dist: 0.0016
# Epoch 35/100
# 411/411 [==============================] - 7s 18ms/step - g_loss: 0.6948 - d_loss: 0.6930 - wass_dist: -0.0188 - g_lr: 0.0010 - d_lr: 6.4706e-04 - val_g_loss: 0.7024 - val_d_loss: 0.6930 - val_wass_dist: -0.0010
# Epoch 36/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6956 - d_loss: 0.6929 - wass_dist: -0.0133 - g_lr: 0.0010 - d_lr: 6.3894e-04 - val_g_loss: 0.6932 - val_d_loss: 0.6928 - val_wass_dist: 0.0050
# Epoch 37/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6957 - d_loss: 0.6930 - wass_dist: -0.0083 - g_lr: 0.0010 - d_lr: 6.3093e-04 - val_g_loss: 0.6982 - val_d_loss: 0.6928 - val_wass_dist: -0.0030
# Epoch 38/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6954 - d_loss: 0.6928 - wass_dist: -4.8816e-04 - g_lr: 9.8353e-04 - d_lr: 6.2302e-04 - val_g_loss: 0.6909 - val_d_loss: 0.6938 - val_wass_dist: 0.0054
# Epoch 39/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6958 - d_loss: 0.6930 - wass_dist: -0.0093 - g_lr: 9.6509e-04 - d_lr: 6.1521e-04 - val_g_loss: 0.6943 - val_d_loss: 0.6925 - val_wass_dist: -0.0107
# Epoch 40/100
# 411/411 [==============================] - 7s 18ms/step - g_loss: 0.6958 - d_loss: 0.6930 - wass_dist: -0.0015 - g_lr: 9.4699e-04 - d_lr: 6.0750e-04 - val_g_loss: 0.6996 - val_d_loss: 0.6932 - val_wass_dist: -9.5473e-04
# Epoch 41/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6953 - d_loss: 0.6930 - wass_dist: -0.0181 - g_lr: 9.2924e-04 - d_lr: 5.9988e-04 - val_g_loss: 0.6909 - val_d_loss: 0.6932 - val_wass_dist: -0.0057
# Epoch 42/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6958 - d_loss: 0.6928 - wass_dist: -0.0083 - g_lr: 9.1181e-04 - d_lr: 5.9236e-04 - val_g_loss: 0.6951 - val_d_loss: 0.6933 - val_wass_dist: -0.0019
# Epoch 43/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6959 - d_loss: 0.6930 - wass_dist: 2.3769e-04 - g_lr: 8.9472e-04 - d_lr: 5.8493e-04 - val_g_loss: 0.6939 - val_d_loss: 0.6929 - val_wass_dist: -0.0034
# Epoch 44/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6953 - d_loss: 0.6929 - wass_dist: -0.0149 - g_lr: 8.7794e-04 - d_lr: 5.7759e-04 - val_g_loss: 0.7001 - val_d_loss: 0.6933 - val_wass_dist: -0.0052
# Epoch 45/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6958 - d_loss: 0.6930 - wass_dist: 0.0065 - g_lr: 8.6148e-04 - d_lr: 5.7035e-04 - val_g_loss: 0.6920 - val_d_loss: 0.6934 - val_wass_dist: -0.0025
# Epoch 46/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6952 - d_loss: 0.6931 - wass_dist: -0.0192 - g_lr: 8.4533e-04 - d_lr: 5.6320e-04 - val_g_loss: 0.6979 - val_d_loss: 0.6934 - val_wass_dist: 0.0049
# Epoch 47/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6962 - d_loss: 0.6926 - wass_dist: -0.0084 - g_lr: 8.2948e-04 - d_lr: 5.5614e-04 - val_g_loss: 0.7010 - val_d_loss: 0.6924 - val_wass_dist: -0.0040
# Epoch 48/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6959 - d_loss: 0.6928 - wass_dist: -0.0164 - g_lr: 8.1393e-04 - d_lr: 5.4917e-04 - val_g_loss: 0.6993 - val_d_loss: 0.6933 - val_wass_dist: 0.0036
# Epoch 49/100
# 411/411 [==============================] - 11s 26ms/step - g_loss: 0.6966 - d_loss: 0.6929 - wass_dist: -9.9330e-04 - g_lr: 7.9867e-04 - d_lr: 5.4228e-04 - val_g_loss: 0.6846 - val_d_loss: 0.6946 - val_wass_dist: -0.0017
# Epoch 50/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6966 - d_loss: 0.6925 - wass_dist: -0.0387 - g_lr: 7.8369e-04 - d_lr: 5.3548e-04 - val_g_loss: 0.6967 - val_d_loss: 0.6927 - val_wass_dist: -0.0047
# Epoch 51/100
# 411/411 [==============================] - 9s 22ms/step - g_loss: 0.6977 - d_loss: 0.6925 - wass_dist: -0.0194 - g_lr: 7.6900e-04 - d_lr: 5.2877e-04 - val_g_loss: 0.6965 - val_d_loss: 0.6923 - val_wass_dist: 0.0016
# Epoch 52/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6966 - d_loss: 0.6926 - wass_dist: -0.0075 - g_lr: 7.5458e-04 - d_lr: 5.2214e-04 - val_g_loss: 0.6999 - val_d_loss: 0.6921 - val_wass_dist: -0.0025
# Epoch 53/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6974 - d_loss: 0.6927 - wass_dist: -0.0174 - g_lr: 7.4043e-04 - d_lr: 5.1559e-04 - val_g_loss: 0.6917 - val_d_loss: 0.6931 - val_wass_dist: 4.3111e-04
# Epoch 54/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6976 - d_loss: 0.6926 - wass_dist: -0.0181 - g_lr: 7.2655e-04 - d_lr: 5.0912e-04 - val_g_loss: 0.6917 - val_d_loss: 0.6915 - val_wass_dist: -0.0043
# Epoch 55/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6981 - d_loss: 0.6924 - wass_dist: 0.0117 - g_lr: 7.1293e-04 - d_lr: 5.0274e-04 - val_g_loss: 0.6909 - val_d_loss: 0.6918 - val_wass_dist: -0.0025
# Epoch 56/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6973 - d_loss: 0.6927 - wass_dist: -0.0180 - g_lr: 6.9956e-04 - d_lr: 4.9644e-04 - val_g_loss: 0.7021 - val_d_loss: 0.6918 - val_wass_dist: -0.0056
# Epoch 57/100
# 411/411 [==============================] - 9s 22ms/step - g_loss: 0.6976 - d_loss: 0.6923 - wass_dist: -0.0263 - g_lr: 6.8645e-04 - d_lr: 4.9021e-04 - val_g_loss: 0.6981 - val_d_loss: 0.6917 - val_wass_dist: -0.0089
# Epoch 58/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6986 - d_loss: 0.6925 - wass_dist: -0.0752 - g_lr: 6.7358e-04 - d_lr: 4.8406e-04 - val_g_loss: 0.7018 - val_d_loss: 0.6932 - val_wass_dist: 6.9477e-04
# Epoch 59/100
# 411/411 [==============================] - 8s 21ms/step - g_loss: 0.6981 - d_loss: 0.6929 - wass_dist: -0.0232 - g_lr: 6.6095e-04 - d_lr: 4.7799e-04 - val_g_loss: 0.6908 - val_d_loss: 0.6947 - val_wass_dist: -0.0133
# Epoch 60/100
# 411/411 [==============================] - 11s 26ms/step - g_loss: 0.6976 - d_loss: 0.6926 - wass_dist: -0.0128 - g_lr: 6.4855e-04 - d_lr: 4.7200e-04 - val_g_loss: 0.6814 - val_d_loss: 0.6941 - val_wass_dist: -0.0045
# Epoch 61/100
# 411/411 [==============================] - 9s 22ms/step - g_loss: 0.6980 - d_loss: 0.6925 - wass_dist: -0.0258 - g_lr: 6.3639e-04 - d_lr: 4.6608e-04 - val_g_loss: 0.6966 - val_d_loss: 0.6934 - val_wass_dist: -0.0082
# Epoch 62/100
# 411/411 [==============================] - 9s 22ms/step - g_loss: 0.6978 - d_loss: 0.6925 - wass_dist: -0.0108 - g_lr: 6.2446e-04 - d_lr: 4.6024e-04 - val_g_loss: 0.7044 - val_d_loss: 0.6930 - val_wass_dist: -0.0034
# Epoch 63/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6979 - d_loss: 0.6926 - wass_dist: -0.0422 - g_lr: 6.1275e-04 - d_lr: 4.5447e-04 - val_g_loss: 0.6955 - val_d_loss: 0.6931 - val_wass_dist: 0.0054
# Epoch 64/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6980 - d_loss: 0.6925 - wass_dist: -0.0282 - g_lr: 6.0127e-04 - d_lr: 4.4877e-04 - val_g_loss: 0.6991 - val_d_loss: 0.6920 - val_wass_dist: -0.0155
# Epoch 65/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6982 - d_loss: 0.6924 - wass_dist: 4.1669e-04 - g_lr: 5.8999e-04 - d_lr: 4.4314e-04 - val_g_loss: 0.6981 - val_d_loss: 0.6933 - val_wass_dist: 0.0052
# Epoch 66/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6981 - d_loss: 0.6923 - wass_dist: -0.0023 - g_lr: 5.7893e-04 - d_lr: 4.3759e-04 - val_g_loss: 0.6974 - val_d_loss: 0.6939 - val_wass_dist: 0.0081
# Epoch 67/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6978 - d_loss: 0.6924 - wass_dist: 0.0015 - g_lr: 5.6808e-04 - d_lr: 4.3210e-04 - val_g_loss: 0.6985 - val_d_loss: 0.6942 - val_wass_dist: -4.3544e-04
# Epoch 68/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6980 - d_loss: 0.6925 - wass_dist: -0.0728 - g_lr: 5.5743e-04 - d_lr: 4.2668e-04 - val_g_loss: 0.6786 - val_d_loss: 0.6922 - val_wass_dist: -0.0206
# Epoch 69/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6980 - d_loss: 0.6923 - wass_dist: -0.0278 - g_lr: 5.4697e-04 - d_lr: 4.2133e-04 - val_g_loss: 0.7005 - val_d_loss: 0.6942 - val_wass_dist: 0.0105
# Epoch 70/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6982 - d_loss: 0.6927 - wass_dist: -0.0468 - g_lr: 5.3672e-04 - d_lr: 4.1605e-04 - val_g_loss: 0.6994 - val_d_loss: 0.6915 - val_wass_dist: -2.7730e-04
# Epoch 71/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6984 - d_loss: 0.6922 - wass_dist: -0.0328 - g_lr: 5.2666e-04 - d_lr: 4.1083e-04 - val_g_loss: 0.6942 - val_d_loss: 0.6929 - val_wass_dist: -5.8546e-04
# Epoch 72/100
# 411/411 [==============================] - 10s 24ms/step - g_loss: 0.6983 - d_loss: 0.6923 - wass_dist: -0.0563 - g_lr: 5.1678e-04 - d_lr: 4.0568e-04 - val_g_loss: 0.7028 - val_d_loss: 0.6925 - val_wass_dist: -0.0037
# Epoch 73/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6991 - d_loss: 0.6919 - wass_dist: -0.0263 - g_lr: 5.0709e-04 - d_lr: 4.0059e-04 - val_g_loss: 0.6890 - val_d_loss: 0.6929 - val_wass_dist: -0.0063
# Epoch 74/100
# 411/411 [==============================] - 9s 21ms/step - g_loss: 0.6986 - d_loss: 0.6922 - wass_dist: -0.0624 - g_lr: 4.9758e-04 - d_lr: 3.9557e-04 - val_g_loss: 0.6955 - val_d_loss: 0.6929 - val_wass_dist: 0.0063
# Epoch 75/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6985 - d_loss: 0.6922 - wass_dist: -0.0045 - g_lr: 4.8825e-04 - d_lr: 3.9061e-04 - val_g_loss: 0.6934 - val_d_loss: 0.6925 - val_wass_dist: -0.0038
# Epoch 76/100
# 411/411 [==============================] - 7s 18ms/step - g_loss: 0.6987 - d_loss: 0.6922 - wass_dist: -0.0019 - g_lr: 4.7910e-04 - d_lr: 3.8571e-04 - val_g_loss: 0.7087 - val_d_loss: 0.6931 - val_wass_dist: -0.0080
# Epoch 77/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6987 - d_loss: 0.6921 - wass_dist: -0.0139 - g_lr: 4.7012e-04 - d_lr: 3.8088e-04 - val_g_loss: 0.7073 - val_d_loss: 0.6947 - val_wass_dist: -0.0114
# Epoch 78/100
# 411/411 [==============================] - 8s 18ms/step - g_loss: 0.6989 - d_loss: 0.6920 - wass_dist: -0.0671 - g_lr: 4.6130e-04 - d_lr: 3.7610e-04 - val_g_loss: 0.6984 - val_d_loss: 0.6913 - val_wass_dist: -0.0228
# Epoch 79/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.7004 - d_loss: 0.6920 - wass_dist: -0.0660 - g_lr: 4.5265e-04 - d_lr: 3.7138e-04 - val_g_loss: 0.6926 - val_d_loss: 0.6937 - val_wass_dist: 0.0118
# Epoch 80/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6989 - d_loss: 0.6922 - wass_dist: -0.0220 - g_lr: 4.4417e-04 - d_lr: 3.6673e-04 - val_g_loss: 0.7090 - val_d_loss: 0.6915 - val_wass_dist: -0.0142
# Epoch 81/100
# 411/411 [==============================] - 7s 18ms/step - g_loss: 0.6987 - d_loss: 0.6920 - wass_dist: -0.0218 - g_lr: 4.3584e-04 - d_lr: 3.6213e-04 - val_g_loss: 0.7032 - val_d_loss: 0.6925 - val_wass_dist: -0.0093
# Epoch 82/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6987 - d_loss: 0.6922 - wass_dist: -0.0063 - g_lr: 4.2767e-04 - d_lr: 3.5759e-04 - val_g_loss: 0.6847 - val_d_loss: 0.6942 - val_wass_dist: -0.0107
# Epoch 83/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6992 - d_loss: 0.6919 - wass_dist: -0.0881 - g_lr: 4.1965e-04 - d_lr: 3.5310e-04 - val_g_loss: 0.7003 - val_d_loss: 0.6916 - val_wass_dist: -0.0168
# Epoch 84/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6997 - d_loss: 0.6919 - wass_dist: -0.0185 - g_lr: 4.1178e-04 - d_lr: 3.4868e-04 - val_g_loss: 0.6897 - val_d_loss: 0.6931 - val_wass_dist: -0.0077
# Epoch 85/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6987 - d_loss: 0.6921 - wass_dist: -0.0313 - g_lr: 4.0406e-04 - d_lr: 3.4430e-04 - val_g_loss: 0.6984 - val_d_loss: 0.6939 - val_wass_dist: 0.0096
# Epoch 86/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6996 - d_loss: 0.6919 - wass_dist: -0.0386 - g_lr: 3.9648e-04 - d_lr: 3.3999e-04 - val_g_loss: 0.6917 - val_d_loss: 0.6923 - val_wass_dist: 0.0035
# Epoch 87/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6987 - d_loss: 0.6920 - wass_dist: -0.0499 - g_lr: 3.8905e-04 - d_lr: 3.3572e-04 - val_g_loss: 0.6880 - val_d_loss: 0.6933 - val_wass_dist: -0.0051
# Epoch 88/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6982 - d_loss: 0.6921 - wass_dist: -0.0128 - g_lr: 3.8176e-04 - d_lr: 3.3151e-04 - val_g_loss: 0.7037 - val_d_loss: 0.6931 - val_wass_dist: -0.0091
# Epoch 89/100
# 411/411 [==============================] - 7s 18ms/step - g_loss: 0.6992 - d_loss: 0.6921 - wass_dist: -0.0663 - g_lr: 3.7460e-04 - d_lr: 3.2736e-04 - val_g_loss: 0.6983 - val_d_loss: 0.6925 - val_wass_dist: 0.0168
# Epoch 90/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6991 - d_loss: 0.6921 - wass_dist: -0.0279 - g_lr: 3.6758e-04 - d_lr: 3.2325e-04 - val_g_loss: 0.6989 - val_d_loss: 0.6938 - val_wass_dist: -0.0156
# Epoch 91/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6991 - d_loss: 0.6920 - wass_dist: -0.0542 - g_lr: 3.6068e-04 - d_lr: 3.1920e-04 - val_g_loss: 0.7187 - val_d_loss: 0.6929 - val_wass_dist: -0.0044
# Epoch 92/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6999 - d_loss: 0.6917 - wass_dist: -0.0239 - g_lr: 3.5392e-04 - d_lr: 3.1520e-04 - val_g_loss: 0.6974 - val_d_loss: 0.6924 - val_wass_dist: -0.0115
# Epoch 93/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6993 - d_loss: 0.6918 - wass_dist: 0.0179 - g_lr: 3.4729e-04 - d_lr: 3.1125e-04 - val_g_loss: 0.6960 - val_d_loss: 0.6919 - val_wass_dist: 0.0017
# Epoch 94/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6996 - d_loss: 0.6919 - wass_dist: -0.0290 - g_lr: 3.4077e-04 - d_lr: 3.0734e-04 - val_g_loss: 0.6849 - val_d_loss: 0.6933 - val_wass_dist: 9.0489e-04
# Epoch 95/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6990 - d_loss: 0.6918 - wass_dist: -0.0345 - g_lr: 3.3438e-04 - d_lr: 3.0349e-04 - val_g_loss: 0.6881 - val_d_loss: 0.6943 - val_wass_dist: -0.0055
# Epoch 96/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6998 - d_loss: 0.6918 - wass_dist: -0.1514 - g_lr: 3.2812e-04 - d_lr: 2.9968e-04 - val_g_loss: 0.6975 - val_d_loss: 0.6904 - val_wass_dist: -0.0172
# Epoch 97/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6992 - d_loss: 0.6918 - wass_dist: -0.0056 - g_lr: 3.2196e-04 - d_lr: 2.9593e-04 - val_g_loss: 0.7009 - val_d_loss: 0.6928 - val_wass_dist: -0.0168
# Epoch 98/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6989 - d_loss: 0.6919 - wass_dist: -0.0222 - g_lr: 3.1593e-04 - d_lr: 2.9222e-04 - val_g_loss: 0.6939 - val_d_loss: 0.6924 - val_wass_dist: -0.0080
# Epoch 99/100
# 411/411 [==============================] - 8s 19ms/step - g_loss: 0.6993 - d_loss: 0.6918 - wass_dist: -0.0135 - g_lr: 3.1000e-04 - d_lr: 2.8855e-04 - val_g_loss: 0.6906 - val_d_loss: 0.6930 - val_wass_dist: -4.4911e-04
# Epoch 100/100
# 411/411 [==============================] - 8s 20ms/step - g_loss: 0.6988 - d_loss: 0.6916 - wass_dist: -0.0281 - g_lr: 3.0419e-04 - d_lr: 2.8493e-04 - val_g_loss: 0.7071 - val_d_loss: 0.6939 - val_wass_dist: -0.0022
# Training procedure completed in 0:14:27.991108

# %% [markdown]
# The following code cells report the **learning** and **metric curves** for the training just finished.

# %% [markdown]
# #### Learning curves

# %%
plt.figure(figsize=(16, 5), dpi=100)

plt.subplot(1, 2, 1)
plt.title("Learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Loss", fontsize=12)
plt.plot(train.history["g_loss"], color="#3288bd", label="generator")
plt.plot(train.history["d_loss"], color="#fc8d59", label="discriminator")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Learning rate scheduling", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Learning rate", fontsize=12)
plt.plot(train.history["g_lr"], color="#3288bd", label="generator")
plt.plot(train.history["d_lr"], color="#fc8d59", label="discriminator")
plt.legend(loc="upper right", fontsize=10)
plt.yscale("log")

plt.show()

# %%
plt.figure(figsize=(16, 5), dpi=100)

plt.subplot(1, 2, 1)
plt.title("Generator learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel(gan.loss_name, fontsize=12)
plt.plot(train.history["g_loss"], color="#d01c8b", label="training set")
plt.plot(train.history["val_g_loss"], color="#4dac26", label="validation set")
plt.legend(loc="upper right", fontsize=10)

plt.subplot(1, 2, 2)
plt.title("Discriminator learning curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel(gan.loss_name, fontsize=12)
plt.plot(train.history["d_loss"], color="#d01c8b", label="training set")
plt.plot(train.history["val_d_loss"], color="#4dac26", label="validation set")
plt.legend(loc="upper right", fontsize=10)

plt.show()

# %% [markdown]
# #### Metric curves

# %%
plt.figure(figsize=(8, 5), dpi=100)

plt.title("Metric curves", fontsize=14)
plt.xlabel("Training epochs", fontsize=12)
plt.ylabel("Wasserstein distance", fontsize=12)
plt.plot(train.history["wass_dist"], color="#d01c8b", label="training set")
plt.plot(train.history["val_wass_dist"], color="#4dac26", label="validation set")
plt.legend(loc="lower left", fontsize=10)

plt.show()

# %% [markdown]
# ### Validation plots
#
# Once trained the GAN system, the **generator model** can be used to parameterize the high-level response of the LHCb RICH detectors, namely the RICH differential log-likelihoods for different particle hypotheses. Let's have a look at the achieved performance on the **test set**!

# %%
x_test_prep = x_scaler.transform(x_test[:, :3])  # input pre-processing
x_test_prep = np.c_[x_test_prep, x_test[:, -1]]

out_test = gan.generate(x_test_prep, seed=None)
out_test_post = y_scaler.inverse_transform(out_test)  # output post-processing

# %% [markdown]
# #### RICH differential log-likelihood $(e - \pi)$

# %%
plt.figure(figsize=(16, 5), dpi=100)

bins = np.linspace(-100.0, 50.0, 101)

for i, scale in enumerate(["linear", "log"]):
    plt.subplot(1, 2, i + 1)
    plt.xlabel("RICH differential log-likelihood $(e - \pi)$", fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_test[:, 0], bins=bins, color="#3288bd", label="toy data")
    plt.hist(out_test_post[:, 0], bins=bins, histtype="step", lw=2, color="#fc8d59", label="BceGAN-ALP model")
    plt.legend(loc="upper left", fontsize=10)
    plt.yscale(scale)

plt.show()

# %% [markdown]
# #### RICH differential log-likelihood $(\mu - \pi)$

# %%
plt.figure(figsize=(16, 5), dpi=100)

bins = np.linspace(-75.0, 75.0, 101)

for i, scale in enumerate(["linear", "log"]):
    plt.subplot(1, 2, i + 1)
    plt.xlabel("RICH differential log-likelihood $(\mu - \pi)$", fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_test[:, 1], bins=bins, color="#3288bd", label="toy data")
    plt.hist(out_test_post[:, 1], bins=bins, histtype="step", lw=2, color="#fc8d59", label="BceGAN-ALP model")
    plt.legend(loc="upper left", fontsize=10)
    plt.yscale(scale)

plt.show()

# %% [markdown]
# #### RICH differential log-likelihood $(K - \pi)$

# %%
plt.figure(figsize=(16, 5), dpi=100)

bins = np.linspace(-150.0, 100.0, 101)

for i, scale in enumerate(["linear", "log"]):
    plt.subplot(1, 2, i + 1)
    plt.xlabel("RICH differential log-likelihood $(K - \pi)$", fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_test[:, 2], bins=bins, color="#3288bd", label="toy data")
    plt.hist(out_test_post[:, 2], bins=bins, histtype="step", lw=2, color="#fc8d59", label="BceGAN-ALP model")
    plt.legend(loc="upper left", fontsize=10)
    plt.yscale(scale)

plt.show()

# %% [markdown]
# #### RICH differential log-likelihood $(p - \pi)$

# %%
plt.figure(figsize=(16, 5), dpi=100)

bins = np.linspace(-150.0, 100.0, 101)

for i, scale in enumerate(["linear", "log"]):
    plt.subplot(1, 2, i + 1)
    plt.xlabel("RICH differential log-likelihood $(p - \pi)$", fontsize=12)
    plt.ylabel("Candidates", fontsize=12)
    plt.hist(y_test[:, 3], bins=bins, color="#3288bd", label="toy data")
    plt.hist(out_test_post[:, 3], bins=bins, histtype="step", lw=2, color="#fc8d59", label="BceGAN-ALP model")
    plt.legend(loc="upper left", fontsize=10)
    plt.yscale(scale)

plt.show()

# %% [markdown]
# ### Model export
#
# The [pidgan](https://github.com/mbarbetti/pidgan) package provides the **generator model** with the `export_model()` to export it as a plain [`Sequential`](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential) model to ease the **deployment** of the RICH parameterization through tools like [scikinC](https://github.com/landerlini/scikinC) or [keras2c](https://github.com/f0uriest/keras2c) [[9][9], [10][10]].
#
# [9]: https://pos.sissa.it/409/034
# [10]: https://doi.org/10.1016/j.engappai.2021.104182

# %%
keras.models.save_model(
    gan.generator.export_model,  # TF Sequential model
    filepath="saved_generator",
    save_format="tf",
)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# Exporting the generator as a [TensorFlow SavedModel format](https://www.tensorflow.org/guide/saved_model) file allows to use **scikinC** to transpile the [`Sequential`](https://www.tensorflow.org/api_docs/python/tf/keras/Sequential) model to a C file as follows:

# %%
# %%capture
# !scikinC saved_generator > generator.C

# %%
# !ls -lrth generator.C
# Out:
# -rw-r--r-- 1 root root 1.8M Nov  7 18:10 generator.C

# %% [markdown]
# ## References
#
# 1. I.J. Goodfellow _et al._, "Generative Adversarial Networks", [arXiv:1406.2661][1]
# 2. M. Arjovsky, L. Bottou, "Towards Principled Methods for Training Generative Adversarial Networks", [arXiv:1701.04862][2]
# 3. M. Arjovsky, S. Chintala, L. Bottou, "Wasserstein GAN", [arXiv:1701.07875][3]
# 4. D. Terjék, "Adversarial Lipschitz Regularization", [arXiv:1907.05681][4]
# 5. A. Radford, L. Metz, S. Chintala, "Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks", [arXiv:1511.06434][5]
# 6. M. Mirza, S. Osindero, "Conditional Generative Adversarial Nets", [arXiv:1411.1784][6]
# 7. A. Maevskiy _et al._, "Fast Data-Driven Simulation of Cherenkov Detectors Using Generative Adversarial Networks", [arXiv:1905.11825][7]
# 8. T. Salimans _et al._, "Improved Techniques for Training GANs", [arXiv:1606.03498][8]
# 9. L. Anderlini, M. Barbetti, "scikinC: a tool for deploying machine learning as binaries", [PoS **CompTools2021** (2022) 034][9]
# 10. R. Conlin _et al._, "Keras2c: A library for converting Keras neural networks to real-time compatible C", [Eng Appl Artif Intell **100** (2021) 104182][10]
#
# [1]: https://arxiv.org/abs/1406.2661
# [2]: https://arxiv.org/abs/1701.04862
# [3]: https://arxiv.org/abs/1701.07875
# [4]: https://arxiv.org/abs/1704.00028
# [5]: https://arxiv.org/abs/1511.06434
# [6]: https://arxiv.org/abs/1411.1784
# [7]: https://arxiv.org/abs/1905.11825
# [8]: https://arxiv.org/abs/1606.03498
# [9]: https://pos.sissa.it/409/034
# [10]: https://doi.org/10.1016/j.engappai.2021.104182

# %% [markdown]
# ## Credits
# This tutorial is based on the notebooks provided by the [mbarbetti/tf-gen-models](https://github.com/mbarbetti/tf-gen-models) repository.
